# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Set style
sns.set(style="whitegrid")

# %%
# Load the synthetic data generated by your script
data_path = '../data/raw_data.csv'

if os.path.exists(data_path):
    df = pd.read_csv(data_path)
    print("Data loaded successfully!")
    display(df.head())
else:
    print("Data not found! Please run 'python data/generate_synthetic_data.py' first.")

# %%
# Visualize how inputs correlate with Noise Level (LAeq)
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()

# %%
# Visualize relationships between variables
# This helps see if relationships are linear or non-linear
sns.pairplot(df, x_vars=['Q', 'V', 'PH', 'G', 'D', 'BRF'], y_vars='LAeq', height=4, aspect=0.8, kind='reg')
plt.show()
